# %% [markdown]
# <a href="https://colab.research.google.com/github/chsaintlouis/HHA504-E2E/blob/main/E2E.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import needed packages

# %%
import sqlalchemy
from sqlalchemy import create_engine
import pandas as pd
# !pip install pymysql
# !pip install cryptography

# %% [markdown]
# ## Load CSV File

# %%
csvfile = pd.read_csv('H1N1_Flu_Vaccines.csv')

# %%
csvfile
# Out:
#        respondent_id  h1n1_concern  ...  h1n1_vaccine  seasonal_vaccine
# 0                  0           1.0  ...             0                 0
# 1                  1           3.0  ...             0                 1
# 2                  2           1.0  ...             0                 0
# 3                  3           1.0  ...             0                 1
# 4                  4           2.0  ...             0                 0
# ...              ...           ...  ...           ...               ...
# 26702          26702           2.0  ...             0                 0
# 26703          26703           1.0  ...             0                 0
# 26704          26704           2.0  ...             0                 1
# 26705          26705           1.0  ...             0                 0
# 26706          26706           0.0  ...             0                 0
#
# [26707 rows x 38 columns]

# %% [markdown]
# ##Connect to SQL instance

# %%
MYSQL_HOSTNAME = '20.120.82.182' # change this to your IP address which is found on your AZURE dashboard 
MYSQL_USER = 'dba'
MYSQL_PASSWORD = 'ahi2020'
MYSQL_DATABASE = 'christest'

connection_string = f'mysql+pymysql://{MYSQL_USER}:{MYSQL_PASSWORD}@{MYSQL_HOSTNAME}/{MYSQL_DATABASE}'
engine = create_engine(connection_string)
print(engine.table_names)
# Out:
# <bound method Engine.table_names of Engine(mysql+pymysql://dba:***@20.120.82.182/christest)>

# %%
connection_string = f'mysql+pymysql://{MYSQL_USER}:{MYSQL_PASSWORD}@{MYSQL_HOSTNAME}:3306/{MYSQL_DATABASE}'
engine = create_engine(connection_string)

# %%
TABLENAME = 'H1N1'

# %%
csvfile.to_sql(TABLENAME, con=engine)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pymysql/connections.py in _read_bytes(self, num_bytes)
#     731             try:
# --> 732                 data = self._rfile.read(num_bytes)
#     733                 break
#
# /usr/lib/python3.7/socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# TimeoutError: [Errno 110] Connection timed out
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1802                     self.dialect.do_execute(
# ...
